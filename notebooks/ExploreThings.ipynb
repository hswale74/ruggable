# %%
import psycopg2
import pandas as pd

def query(
    query_text, 
    host = "localhost",
    port = 5432,
    database = "postgres",
    user = "postgres",
    password = "postgres"):
    
    with psycopg2.connect(
                        host=host,
                        port=port,
                        database=database,
                        user=user,
                        password=password
                    ) as conn:
        cur = conn.cursor()
        cur.execute(query_text)
        results = cur.fetchall()
        column_names = [desc[0] for desc in cur.description]

    return_df = pd.DataFrame.from_records(results)
    return_df.columns = column_names
    return return_df


class PkScout:
    
    def __init__(self, table_name):
        self.table_name = table_name
        
        info_schema_query = f"""
            SELECT 
            column_name, 
            data_type, 
            is_nullable, 
            character_maximum_length, 
            numeric_precision, 
            numeric_scale
            FROM information_schema.columns
            WHERE table_schema = 'public'
            AND table_name = '{self.table_name}';
        """

        self.info_schema_df = query(info_schema_query)
        self.table_row_count = int(query(
            f"""
            Select count(1) as ct 
            from (Select distinct * from {self.table_name}) foo
            """
        )['ct'].iloc[0])

    def get_column_cardinalities(self, descending=True):
        column_cardinalities = []
        for column in self.info_schema_df['column_name']:
            column_cardinality = int(
                query(
                    f'Select count(distinct "{column}") as ct from {self.table_name}'
                )['ct'].iloc[0]
            )
            
            column_cardinalities.append((column, column_cardinality))

        return sorted(column_cardinalities, key=lambda x: x[1], reverse=descending)

    def compute_joint_cardinality(self, columns):
        columns = [f'"{name}"' for name in columns]

        return int(query(
                    f"""
                        Select count(1) as ct
                        from (
                            Select distinct {','.join(columns)}
                            from {self.table_name}
                        ) as foo
                    """
                )['ct'].iloc[0])

    def find_pk(self, descending=True):
        column_cardinalities = self.get_column_cardinalities(descending)

        joint_cardinalities = []
        for index, (column, cardinality) in enumerate(column_cardinalities):
            if cardinality == self.table_row_count:
                print(f"{column} is a candidate: Same cardinality as table row count = {self.table_row_count}")

            for i in range(1, len(column_cardinalities)-index-1):
                joint_columns = [name for name, _ in column_cardinalities[index:index+i+1]]
                joint_cardinality = self.compute_joint_cardinality(joint_columns)

                joint_cardinalities.append(
                    (
                        tuple([x.replace('"','') for x in joint_columns]),
                        joint_cardinality
                    )
                )
                
                if joint_cardinality == self.table_row_count:
                    print(f"{joint_columns} are a candidate: Same cardinality as table row count = {self.table_row_count}")
                    break


        return joint_cardinalities

# %%
TABLES = [
    'rugs_usa_category_map',
    'rugs_usa_color_map',
    'rugs_usa_links',
    'rugs_usa_pads_upsell',
    'rugs_usa_parent',
    'rugs_usa_variant'
]

# %%
for table in TABLES:
    schema_query = f"""
    SELECT 
        column_name, 
        data_type, 
        is_nullable, 
        character_maximum_length, 
        numeric_precision, 
        numeric_scale
    FROM information_schema.columns
    WHERE table_schema = 'public'
    AND table_name = '{table}';
    """
    print(f"*****{table}*****")
    display(
        query(
            schema_query
        )
    )
# Out:
# *****rugs_usa_category_map*****
#            column_name data_type is_nullable character_maximum_length  \
# 0                  pid      text         YES                     None
# 1          category_id      text         YES                     None
# 2       category_value      text         YES                     None
# 3  dw_insert_timestamp      text         YES                     None
#
#   numeric_precision numeric_scale
# 0              None          None
# 1              None          None
# 2              None          None
# 3              None          None
# *****rugs_usa_color_map*****
#            column_name data_type is_nullable character_maximum_length  \
# 0                  pid      text         YES                     None
# 1             color_id      text         YES                     None
# 2          color_value      text         YES                     None
# 3  dw_insert_timestamp      text         YES                     None
#
#   numeric_precision numeric_scale
# 0              None          None
# 1              None          None
# 2              None          None
# 3              None          None
# *****rugs_usa_links*****
#            column_name data_type is_nullable character_maximum_length  \
# 0             base_url      text         YES                     None
# 1           page_links      text         YES                     None
# 2           card_links      text         YES                     None
# 3   request_time_stamp      text         YES                     None
# 4  dw_insert_timestamp      text         YES                     None
#
#   numeric_precision numeric_scale
# 0              None          None
# 1              None          None
# 2              None          None
# 3              None          None
# 4              None          None
# *****rugs_usa_pads_upsell*****
#             column_name         data_type is_nullable  \
# 0                  size              text         YES
# 1                 shape              text         YES
# 2                 price  double precision         YES
# 3                 width  double precision         YES
# 4                  sqft  double precision         YES
# 5                  type              text         YES
# 6                 stock           integer         YES
# 7                height  double precision         YES
# 8               variant              text         YES
# 9                  p_id              text         YES
# 10               pad_id              text         YES
# 11  dw_insert_timestamp              text         YES
#
#    character_maximum_length  numeric_precision  numeric_scale
# 0                      None                NaN            NaN
# 1                      None                NaN            NaN
# 2                      None               53.0            NaN
# 3                      None               53.0            NaN
# 4                      None               53.0            NaN
# 5                      None                NaN            NaN
# 6                      None               32.0            0.0
# 7                      None               53.0            NaN
# 8                      None                NaN            NaN
# 9                      None                NaN            NaN
# 10                     None                NaN            NaN
# 11                     None                NaN            NaN
# *****rugs_usa_parent*****
#             column_name data_type is_nullable character_maximum_length  \
# 0                   pid      text         YES                     None
# 1       product_type_id      text         YES                     None
# 2                  name      text         YES                     None
# 3                   url      text         YES                     None
# 4                origin      text         YES                     None
# 5             thickness      text         YES                     None
# 6              material      text         YES                     None
# 7                 weave   integer         YES                     None
# 8         weave_feature      text         YES                     None
# 9                 color      text         YES                     None
# 10                brand      text         YES                     None
# 11            imageName      text         YES                     None
# 12            imageType      text         YES                     None
# 13         internalName      text         YES                     None
# 14             category      text         YES                     None
# 15            min_price   integer         YES                     None
# 16            max_price   integer         YES                     None
# 17         availability      text         YES                     None
# 18            aggregate   boolean         YES                     None
# 19            clearance      text         YES                     None
# 20     long_description      text         YES                     None
# 21           shopbyroom      text         YES                     None
# 22  dw_insert_timestamp      text         YES                     None
#
#     numeric_precision  numeric_scale
# 0                 NaN            NaN
# 1                 NaN            NaN
# 2                 NaN            NaN
# 3                 NaN            NaN
# 4                 NaN            NaN
# 5                 NaN            NaN
# 6                 NaN            NaN
# 7                32.0            0.0
# 8                 NaN            NaN
# 9                 NaN            NaN
# 10                NaN            NaN
# 11                NaN            NaN
# 12                NaN            NaN
# 13                NaN            NaN
# 14                NaN            NaN
# 15               32.0            0.0
# 16               32.0            0.0
# 17                NaN            NaN
# 18                NaN            NaN
# 19                NaN            NaN
# 20                NaN            NaN
# 21                NaN            NaN
# 22                NaN            NaN
# *****rugs_usa_variant*****
#                 column_name         data_type is_nullable  \
# 0                       pid              text         YES
# 1                   variant              text         YES
# 2               actual_size              text         YES
# 3             weave_feature              text         YES
# 4                 weave_cat              text         YES
# 5                  size_grp              text         YES
# 6             shipping_size              text         YES
# 7                     shape              text         YES
# 8                    weight  double precision         YES
# 9                     price  double precision         YES
# 10                     msrp  double precision         YES
# 11              stock_level           integer         YES
# 12          depletion_level           integer         YES
# 13                low_stock           boolean         YES
# 14  estimated_delivery_date              text         YES
# 15           this_isd_range              text         YES
# 16                   status              text         YES
# 17                   origin              text         YES
# 18              new_arrival              text         YES
# 19                 stockMsg              text         YES
# 20              stockEddMsg              text         YES
# 21         other_stock_core           integer         YES
# 22      other_stock_compass           integer         YES
# 23      dw_insert_timestamp              text         YES
#
#    character_maximum_length  numeric_precision  numeric_scale
# 0                      None                NaN            NaN
# 1                      None                NaN            NaN
# 2                      None                NaN            NaN
# 3                      None                NaN            NaN
# 4                      None                NaN            NaN
# 5                      None                NaN            NaN
# 6                      None                NaN            NaN
# 7                      None                NaN            NaN
# 8                      None               53.0            NaN
# 9                      None               53.0            NaN
# 10                     None               53.0            NaN
# 11                     None               32.0            0.0
# 12                     None               32.0            0.0
# 13                     None                NaN            NaN
# 14                     None                NaN            NaN
# 15                     None                NaN            NaN
# 16                     None                NaN            NaN
# 17                     None                NaN            NaN
# 18                     None                NaN            NaN
# 19                     None                NaN            NaN
# 20                     None                NaN            NaN
# 21                     None               32.0            0.0
# 22                     None               32.0            0.0
# 23                     None                NaN            NaN

# %% [markdown]
# # DW Insert Timestamp?

# %%
for table in TABLES:
    print(table)
    display(query(f"Select distinct dw_insert_timestamp from {table}"))
    display(query(f"Select distinct dw_insert_timestamp::timestamptz from {table}"))
# Out:
# rugs_usa_category_map
#           dw_insert_timestamp
# 0  2022-01-13 19:33:41.514826
#                dw_insert_timestamp
# 0 2022-01-13 19:33:41.514826+00:00
# rugs_usa_color_map
#           dw_insert_timestamp
# 0  2022-01-13 19:33:41.514414
#                dw_insert_timestamp
# 0 2022-01-13 19:33:41.514414+00:00
# rugs_usa_links
#           dw_insert_timestamp
# 0  2022-01-13 19:33:41.512911
#                dw_insert_timestamp
# 0 2022-01-13 19:33:41.512911+00:00
# rugs_usa_pads_upsell
#           dw_insert_timestamp
# 0  2022-01-13 20:44:54.227965
#                dw_insert_timestamp
# 0 2022-01-13 20:44:54.227965+00:00
# rugs_usa_parent
#           dw_insert_timestamp
# 0  2022-01-13 19:33:41.513542
#                dw_insert_timestamp
# 0 2022-01-13 19:33:41.513542+00:00
# rugs_usa_variant
#           dw_insert_timestamp
# 0  2022-01-13 19:33:41.513970
#                dw_insert_timestamp
# 0 2022-01-13 19:33:41.513970+00:00

# %% [markdown]
# # Rugs usa variant

# %%
scout = PkScout('rugs_usa_variant')
joint = scout.find_pk()
# Out:
# ['msrp', 'pid', 'price', 'stock_level', 'weight', 'shipping_size', 'variant'] are a candidate: Same cardinality as table row count = 38569
# ['pid', 'price', 'stock_level', 'weight', 'shipping_size', 'variant'] are a candidate: Same cardinality as table row count = 38569

# %%
scout.compute_joint_cardinality(['pid', 'variant'])
# Out:
# 38569

# %%
scout.compute_joint_cardinality(['variant'])
# Out:
# 587

# %%
scout.compute_joint_cardinality(['actual_size', 'shape'])
# Out:
# 536

# %%
df = query(
    """
    Select variant, count(distinct pid),
    count(distinct actual_size), count(distinct shape), count(distinct weight)
    from rugs_usa_variant group by 1 order by 2 desc""")

# %%
df = query(
    """
    Select variant, pid,
    count(distinct actual_size), count(distinct shape), count(distinct weight)
    from rugs_usa_variant group by 1,2 order by 5 desc""")

# %%
df
# Out:
#       variant       pid  count  count  count
# 0          10   108BT19      1      1      1
# 1          10   108BT29      1      1      1
# 2          10   108CA09      1      1      1
# 3          10   108CA99      1      1      1
# 4          10   108CC29      1      1      1
# ...       ...       ...    ...    ...    ...
# 38564  SAMPLE  108SM501      1      1      1
# 38565  SAMPLE  108SM601      1      1      1
# 38566  SAMPLE  108SM801      1      1      1
# 38567  SAMPLE   108TL50      1      1      1
# 38568  SAMPLE   108TL60      1      1      1
#
# [38569 rows x 5 columns]

# %%
for col in ['actual_size', 'size_grp', 'weave_cat', 'shape', 'origin']:
    display(query(f"Select coalesce(cast({col} as varchar), 'missing') as {col}, count(1) from rugs_usa_variant group by 1 order by 2 desc").head(50))
# Out:
#                  actual_size  count
# 0                5_ft x 8_ft   2741
# 1                4_ft x 6_ft   2329
# 2               8_ft x 10_ft   2204
# 3               9_ft x 12_ft   1476
# 4                3_ft x 5_ft   1369
# 5           6_ft 7_in x 9_ft   1298
# 6                2_ft x 3_ft   1059
# 7                6_ft x 9_ft   1048
# 8                       8_ft    962
# 9                       6_ft    924
# 10          2_ft 6_in x 8_ft    864
# 11     7_ft 6_in x 9_ft 6_in    795
# 12    3_ft 10_in x 5_ft 4_in    654
# 13     5_ft 4_in x 7_ft 8_in    651
# 14              8_ft x 11_ft    590
# 15     5_ft 3_in x 7_ft 6_in    532
# 16                 7_ft 7_in    530
# 17                      4_ft    517
# 18          2_ft 8_in x 8_ft    510
# 19    7_ft 8_in x 10_ft 9_in    505
# 20             12_ft x 15_ft    497
# 21             10_ft x 14_ft    494
# 22     5_ft 3_in x 7_ft 7_in    429
# 23   10_ft 9_in x 13_ft 2_in    409
# 24          2_ft 6_in x 6_ft    400
# 25               2_ft x 8_ft    396
# 26     2_ft 1_in x 7_ft 8_in    384
# 27    2_ft 8_in x 3_ft 10_in    382
# 28             10_ft x 13_ft    358
# 29                      5_ft    356
# 30               7_ft x 9_ft    341
# 31                     10_ft    316
# 32          5_ft x 7_ft 5_in    314
# 33         2_ft 6_in x 10_ft    309
# 34   7_ft 10_in x 10_ft 6_in    288
# 35               2_ft x 6_ft    276
# 36               2_ft x 4_ft    276
# 37               5_ft x 7_ft    249
# 38     6_ft 7_in x 9_ft 6_in    239
# 39  7_ft 10_in x 10_ft 10_in    235
# 40         2_ft 6_in x 12_ft    235
# 41                     12_ft    233
# 42                      3_ft    229
# 43     5_ft 3_in x 7_ft 3_in    227
# 44    8_ft 6_in x 11_ft 6_in    225
# 45     3_ft 6_in x 5_ft 6_in    214
# 46                7_ft 10_in    207
# 47        7_ft 10_in x 10_ft    183
# 48     2_ft 3_in x 7_ft 6_in    171
# 49                 5_ft 3_in    160
#     size_grp  count
# 0        5x8   6767
# 1     Runner   6164
# 2       8x10   5688
# 3        6x9   5132
# 4        3x5   3270
# 5        4x6   3198
# 6        2x3   2944
# 7       9x12   2908
# 8      10x14   1485
# 9   Oversize   1079
# 10     Other    140
# 11    Swatch     25
#       weave_cat  count
# 0  Machine Made  23855
# 1       Braided   8225
# 2   Hand Tufted   4314
# 3     Flatweave   1949
# 4   Hand Hooked    341
# 5  Hand Knotted    109
# 6       missing      7
#                shape  count
# 0          Rectangle  24199
# 1             Runner   5923
# 2              Round   3075
# 3               Oval   3005
# 4             Square   2294
# 5            Octagon    108
# 6        Stair Tread     62
# 7             Shaped     51
# 8   Oval Stair Tread     43
# 9             Hearth     28
# 10            Kidney      7
# 11  Square Chair Pad      5
#     origin  count
# 0  missing  38189
# 1    China    371
# 2   Turkey    132
# 3      SAU    108

# %%
query("Select status, max(stock_level), min(stock_level), max(depletion_level), min(depletion_level) from rugs_usa_variant group by 1")
# Out:
#          status         max  min     max  min
# 0      In_stock  2147483647    1  1008.0  0.0
# 1  Back_ordered           0 -251   266.0  0.0
# 2     Pre_order           0  -48     NaN  NaN
# 3  Out_of_stock           6  -73    42.0  0.0

# %%
query("Select round(stock_level,-2), round(depletion_level,-2), status, count(1) from rugs_usa_variant group by 1,2,3 order by 4 desc").head(20)
# Out:
#          round round        status  count
# 0            0  None      In_stock   8680
# 1            0     0      In_stock   7819
# 2          100  None      In_stock   6321
# 3            0  None  Out_of_stock   4080
# 4          200  None      In_stock   3096
# 5          100     0      In_stock   2709
# 6            0     0  Out_of_stock   1540
# 7   2147483600  None      In_stock    985
# 8            0     0  Back_ordered    829
# 9          200     0      In_stock    681
# 10           0  None  Back_ordered    345
# 11         300     0      In_stock    256
# 12           0  None     Pre_order    177
# 13         300  None      In_stock    174
# 14         400     0      In_stock    143
# 15         400  None      In_stock     96
# 16         500     0      In_stock     90
# 17         500  None      In_stock     70
# 18         600     0      In_stock     53
# 19         600  None      In_stock     36

# %%
query("Select distinct coalesce(new_arrival, 'foo') from rugs_usa_variant")
# Out:
#   coalesce
# 0        Y
# 1        N

# %% [markdown]
# # Rugs usa parent

# %%
query("Select * from rugs_usa_parent")
# Out:
#              pid product_type_id                    name  \
# 0      200TAJT03             RUG            Jute Braided
# 1        200CB01             RUG   Veronica Wool Braided
# 2     200HMMT01A             RUG        Handwoven Chaste
# 3     200RZBD16A             RUG        Moroccan Trellis
# 4      200TAJT03             RUG            Jute Braided
# ...          ...             ...                     ...
# 5557     108BN19             RUG  Braided Indoor/Outdoor
# 5558     108BN19             RUG  Braided Indoor/Outdoor
# 5559     108BN19             RUG  Braided Indoor/Outdoor
# 5560     108BN19             RUG  Braided Indoor/Outdoor
# 5561     108BN19             RUG  Braided Indoor/Outdoor
#
#                                                     url  origin thickness  \
# 0     /rugsusa/rugs/rugs-usa-jute-braided/Natural/20...   India  1/4 inch
# 1     /rugsusa/rugs/rugs-usa-veronica-wool-braided/O...   India  1/2 inch
# 2     /rugsusa/rugs/rugs-usa-handwoven-chaste/Natura...   India  1/4 inch
# 3     /rugsusa/rugs/rugs-usa-moroccan-trellis/Gray/2...  Turkey  1/2 inch
# 4     /rugsusa/rugs/rugs-usa-jute-braided/Off-White/...   India  1/4 inch
# ...                                                 ...     ...       ...
# 5557  /rugsusa/rugs/colonial-mills-braided-indoorout...     USA      None
# 5558  /rugsusa/rugs/colonial-mills-braided-indoorout...     USA      None
# 5559  /rugsusa/rugs/colonial-mills-braided-indoorout...     USA      None
# 5560  /rugsusa/rugs/colonial-mills-braided-indoorout...     USA      None
# 5561  /rugsusa/rugs/colonial-mills-braided-indoorout...     USA      None
#
#                   material weave weave_feature       color           brand  \
# 0                100% Jute  None    Hand Woven     Natural        Rugs USA
# 1     80% Wool, 20% Cotton  None       Braided   Off White        Rugs USA
# 2     60% Jute, 40% Cotton  None   Hand Loomed     Natural        Rugs USA
# 3       100% Polypropylene  None  Machine Made        Gray        Rugs USA
# 4                100% Jute  None    Hand Woven     Natural        Rugs USA
# ...                    ...   ...           ...         ...             ...
# 5557    100% Polypropylene  None       Braided  Brownstone  Colonial Mills
# 5558    100% Polypropylene  None       Braided  Brownstone  Colonial Mills
# 5559    100% Polypropylene  None       Braided  Brownstone  Colonial Mills
# 5560    100% Polypropylene  None       Braided  Brownstone  Colonial Mills
# 5561    100% Polypropylene  None       Braided  Brownstone  Colonial Mills
#
#        imageName  imageType                          internalName   category  \
# 0      200TAJT03  roomImage                 rugs-usa-jute-braided       Maui
# 1        200CB01  roomImage        rugs-usa-veronica-wool-braided   Textures
# 2     200HMMT01A  roomImage             rugs-usa-handwoven-chaste      Fawna
# 3     200RZBD16A  roomImage             rugs-usa-moroccan-trellis  Bosphorus
# 4      200TAJT03  roomImage                 rugs-usa-jute-braided       Maui
# ...          ...        ...                                   ...        ...
# 5557     108BN19          s  colonial-mills-braided-indooroutdoor   Brooklyn
# 5558     108BN19          s  colonial-mills-braided-indooroutdoor   Brooklyn
# 5559     108BN19          s  colonial-mills-braided-indooroutdoor   Brooklyn
# 5560     108BN19          s  colonial-mills-braided-indooroutdoor   Brooklyn
# 5561     108BN19          s  colonial-mills-braided-indooroutdoor   Brooklyn
#
#       min_price  max_price availability  aggregate clearance  \
# 0             0          0     48 Hours       True         N
# 1             0          0     48 Hours       True         N
# 2             0          0     48 Hours       True         N
# 3             0          0     48 Hours       True         N
# 4             0          0     48 Hours       True         N
# ...         ...        ...          ...        ...       ...
# 5557          0          0       5 Days       True         N
# 5558          0          0       5 Days       True         N
# 5559          0          0       5 Days       True         N
# 5560          0          0       5 Days       True         N
# 5561          0          0       5 Days       True         N
#
#                                        long_description  \
# 0     This handmade 100% jute rug is a stylish and e...
# 1     Handcrafted in the style of a chunky knit swea...
# 2     Handmade with luxuriously soft jute and cotton...
# 3     <p class="h4">Named "The Rug" by The New York ...
# 4     This handmade 100% jute rug is a stylish and e...
# ...                                                 ...
# 5557  A combination of alternating braid constructio...
# 5558  A combination of alternating braid constructio...
# 5559  A combination of alternating braid constructio...
# 5560  A combination of alternating braid constructio...
# 5561  A combination of alternating braid constructio...
#
#                                              shopbyroom  \
# 0     Bedroom, Dining Room, Living Room, Hallway, Of...
# 1                                  Bedroom, Living Room
# 2     Bedroom, Dining Room, Living Room, Hallway, Of...
# 3     Bedroom, Dining Room, Living Room, Hallway, Of...
# 4     Bedroom, Dining Room, Living Room, Hallway, Of...
# ...                                                 ...
# 5557                                               None
# 5558                                               None
# 5559                                               None
# 5560                                               None
# 5561                                               None
#
#              dw_insert_timestamp
# 0     2022-01-13 19:33:41.513542
# 1     2022-01-13 19:33:41.513542
# 2     2022-01-13 19:33:41.513542
# 3     2022-01-13 19:33:41.513542
# 4     2022-01-13 19:33:41.513542
# ...                          ...
# 5557  2022-01-13 19:33:41.513542
# 5558  2022-01-13 19:33:41.513542
# 5559  2022-01-13 19:33:41.513542
# 5560  2022-01-13 19:33:41.513542
# 5561  2022-01-13 19:33:41.513542
#
# [5562 rows x 23 columns]

# %%
scout = PkScout('rugs_usa_parent')
joint = scout.find_pk()
# Out:
# url is a candidate: Same cardinality as table row count = 5547
# ['url', 'pid'] are a candidate: Same cardinality as table row count = 5547

# %%
scout.compute_joint_cardinality(['pid', 'name', 'color'])
# Out:
# 3404

# %%
query(
    "Select distinct pid, split_part(url, '/', 5) from rugs_usa_parent" 
)
# Out:
#              pid split_part
# 0       1328007A      Thyme
# 1     200ZHSS01A      Black
# 2     1520301350  Red-Black
# 3        132332C       Blue
# 4      139182803      Green
# ...          ...        ...
# 5542  200GBCB15A       Blue
# 5543  200HJAM02A       Gray
# 5544   287FA170B  Dark-Gray
# 5545  200KKEL01A       Blue
# 5546   279SHICHA       Sand
#
# [5547 rows x 2 columns]

# %%
for col in ['product_type_id']:
    display(query(f"Select {col}, count(1) from rugs_usa_parent group by 1 order by 2 desc"))
# Out:
#   product_type_id  count
# 0             RUG   5562

# %%
for col in ['origin', 'thickness', 'material', 'weave', 'weave_feature', 'availability']:
    display(query(f"Select coalesce(cast({col} as varchar), 'missing') as {col}, count(1) from rugs_usa_parent group by 1 order by 2 desc"))
# Out:
#           origin  count
# 0         Turkey   2329
# 1          India   1369
# 2            USA    864
# 3          China    559
# 4          Egypt    271
# 5        Belgium    116
# 6   Saudi Arabia     22
# 7   China/Turkey     13
# 8    China/India      7
# 9     Bangladesh      6
# 10        Greece      4
# 11        Brazil      2
#     thickness  count
# 0     missing   2553
# 1    1/2 inch   1329
# 2    1/4 inch   1171
# 3      1 inch    137
# 4    3/4 inch    134
# 5  1 1/4 inch    128
# 6      2 inch     45
# 7  1 3/4 inch     29
# 8       1 1/4     22
# 9  1 1/2 inch     14
#                                material  count
# 0                    100% Polypropylene   1911
# 1                        100% Polyester    760
# 2                             100% Wool    431
# 3                            100% Nylon    303
# 4                           100% Olefin    177
# ..                                  ...    ...
# 268            Polypropylene, Polyester      1
# 269               50% Jute, 50% Leather      1
# 270                              Olefin      1
# 271  100% Recycled Polyester Flock Face      1
# 272   60% Wool, 20% Viscose, 20% Cotton      1
#
# [273 rows x 2 columns]
#      weave  count
# 0  missing   5562
#               weave_feature  count
# 0              Machine Made   3545
# 1               Hand Tufted    439
# 2                   Braided    298
# 3             Machine Woven    249
# 4                Hand Woven    236
# 5                 Flatweave    189
# 6                  Handmade    163
# 7               Hand Loomed    112
# 8              Power Loomed     61
# 9               Hand Hooked     48
# 10             Hand Braided     46
# 11          Machine Braided     37
# 12             Hand Knotted     25
# 13                  Printed     22
# 14             Hand Crafted     16
# 15                Hand Made     11
# 16           Machine Tufted     10
# 17                  missing      8
# 18            Hand Handloom      7
# 19               Flat Braid      5
# 20                Flatwoven      5
# 21            Hand Stitched      4
# 22         Circular Knitted      3
# 23              Hand-Tufted      3
# 24               Hand-woven      3
# 25                Handwoven      3
# 26              Hand Looped      3
# 27          Machine Printed      3
# 28              Handcrafted      2
# 29               Loom Woven      1
# 30               Hemp Woven      1
# 31              Pile Hooked      1
# 32       Hand-Woven Dhurrie      1
# 33  Printed Recycled Rubber      1
# 34    Printed Heat Transfer      1
#            availability  count
# 0              48 Hours   3626
# 1            3 - 5 Days    841
# 2              1-3 Days    309
# 3          14 - 16 Days    267
# 4                5 Days    215
# 5              3-5 Days    155
# 6          12 - 14 Days     58
# 7           7 - 10 Days     40
# 8   3 - 5 Business Days     18
# 9              2-3 Days     12
# 10           10-14 Days      8
# 11         14 - 21 Days      8
# 12           1 - 2 Days      3
# 13           5 - 7 Days      2

# %% [markdown]
# ## Url, pid, color

# %%
query("Select url, color, split_part(url, '/', 5) from rugs_usa_parent")
# Out:
#                                                     url       color  \
# 0     /rugsusa/rugs/rugs-usa-jute-braided/Natural/20...     Natural
# 1     /rugsusa/rugs/rugs-usa-veronica-wool-braided/O...   Off White
# 2     /rugsusa/rugs/rugs-usa-handwoven-chaste/Natura...     Natural
# 3     /rugsusa/rugs/rugs-usa-moroccan-trellis/Gray/2...        Gray
# 4     /rugsusa/rugs/rugs-usa-jute-braided/Off-White/...     Natural
# ...                                                 ...         ...
# 5557  /rugsusa/rugs/colonial-mills-braided-indoorout...  Brownstone
# 5558  /rugsusa/rugs/colonial-mills-braided-indoorout...  Brownstone
# 5559  /rugsusa/rugs/colonial-mills-braided-indoorout...  Brownstone
# 5560  /rugsusa/rugs/colonial-mills-braided-indoorout...  Brownstone
# 5561  /rugsusa/rugs/colonial-mills-braided-indoorout...  Brownstone
#
#       split_part
# 0        Natural
# 1      Off-White
# 2        Natural
# 3           Gray
# 4      Off-White
# ...          ...
# 5557     Natural
# 5558  Terracotta
# 5559   Blue-Haze
# 5560       Slate
# 5561  Brownstone
#
# [5562 rows x 3 columns]

# %%
df['color2'] = df['url'].str.split("/").apply(lambda x: x[-2])

# %%
df[['pid', 'color2']].drop_duplicates().shape
# Out:
# (5547, 2)

# %% [markdown]
# ## min price, max price, availability

# %%
df[['min_price', 'max_price']].mean()
# Out:
# min_price    0.0
# max_price    0.0
# dtype: float64

# %%
df['availability'].value_counts()
# Out:
# availability
# 48 Hours               3617
# 3 - 5 Days              841
# 1-3 Days                308
# 14 - 16 Days            267
# 5 Days                  210
# 3-5 Days                155
# 12 - 14 Days             58
# 7 - 10 Days              40
# 3 - 5 Business Days      18
# 2-3 Days                 12
# 10-14 Days                8
# 14 - 21 Days              8
# 1 - 2 Days                3
# 5 - 7 Days                2
# Name: count, dtype: int64

# %%
pd.set_option('display.max_columns', None)
query("Select * from rugs_usa_parent where pid = '108BR12'")
# Out:
#         pid product_type_id                    name  \
# 0   108BR12             RUG  Braided Indoor/Outdoor
# 1   108BR12             RUG  Braided Indoor/Outdoor
# 2   108BR12             RUG  Braided Indoor/Outdoor
# 3   108BR12             RUG  Braided Indoor/Outdoor
# 4   108BR12             RUG  Braided Indoor/Outdoor
# 5   108BR12             RUG  Braided Indoor/Outdoor
# 6   108BR12             RUG  Braided Indoor/Outdoor
# 7   108BR12             RUG  Braided Indoor/Outdoor
# 8   108BR12             RUG  Braided Indoor/Outdoor
# 9   108BR12             RUG  Braided Indoor/Outdoor
# 10  108BR12             RUG  Braided Indoor/Outdoor
# 11  108BR12             RUG  Braided Indoor/Outdoor
# 12  108BR12             RUG  Braided Indoor/Outdoor
# 13  108BR12             RUG  Braided Indoor/Outdoor
# 14  108BR12             RUG  Braided Indoor/Outdoor
# 15  108BR12             RUG  Braided Indoor/Outdoor
# 16  108BR12             RUG  Braided Indoor/Outdoor
# 17  108BR12             RUG  Braided Indoor/Outdoor
# 18  108BR12             RUG  Braided Indoor/Outdoor
# 19  108BR12             RUG  Braided Indoor/Outdoor
# 20  108BR12             RUG  Braided Indoor/Outdoor
# 21  108BR12             RUG  Braided Indoor/Outdoor
# 22  108BR12             RUG  Braided Indoor/Outdoor
# 23  108BR12             RUG  Braided Indoor/Outdoor
# 24  108BR12             RUG  Braided Indoor/Outdoor
# 25  108BR12             RUG  Braided Indoor/Outdoor
# 26  108BR12             RUG  Braided Indoor/Outdoor
# 27  108BR12             RUG  Braided Indoor/Outdoor
# 28  108BR12             RUG  Braided Indoor/Outdoor
#
#                                                   url origin thickness  \
# 0   /rugsusa/rugs/colonial-mills-braided-indoorout...    USA      None
# 1   /rugsusa/rugs/colonial-mills-braided-indoorout...    USA      None
# 2   /rugsusa/rugs/colonial-mills-braided-indoorout...    USA      None
# 3   /rugsusa/rugs/colonial-mills-braided-indoorout...    USA      None
# 4   /rugsusa/rugs/colonial-mills-braided-indoorout...    USA      None
# 5   /rugsusa/rugs/colonial-mills-braided-indoorout...    USA      None
# 6   /rugsusa/rugs/colonial-mills-braided-indoorout...    USA      None
# 7   /rugsusa/rugs/colonial-mills-braided-indoorout...    USA      None
# 8   /rugsusa/rugs/colonial-mills-braided-indoorout...    USA      None
# 9   /rugsusa/rugs/colonial-mills-braided-indoorout...    USA      None
# 10  /rugsusa/rugs/colonial-mills-braided-indoorout...    USA      None
# 11  /rugsusa/rugs/colonial-mills-braided-indoorout...    USA      None
# 12  /rugsusa/rugs/colonial-mills-braided-indoorout...    USA      None
# 13  /rugsusa/rugs/colonial-mills-braided-indoorout...    USA      None
# 14  /rugsusa/rugs/colonial-mills-braided-indoorout...    USA      None
# 15  /rugsusa/rugs/colonial-mills-braided-indoorout...    USA      None
# 16  /rugsusa/rugs/colonial-mills-braided-indoorout...    USA      None
# 17  /rugsusa/rugs/colonial-mills-braided-indoorout...    USA      None
# 18  /rugsusa/rugs/colonial-mills-braided-indoorout...    USA      None
# 19  /rugsusa/rugs/colonial-mills-braided-indoorout...    USA      None
# 20  /rugsusa/rugs/colonial-mills-braided-indoorout...    USA      None
# 21  /rugsusa/rugs/colonial-mills-braided-indoorout...    USA      None
# 22  /rugsusa/rugs/colonial-mills-braided-indoorout...    USA      None
# 23  /rugsusa/rugs/colonial-mills-braided-indoorout...    USA      None
# 24  /rugsusa/rugs/colonial-mills-braided-indoorout...    USA      None
# 25  /rugsusa/rugs/colonial-mills-braided-indoorout...    USA      None
# 26  /rugsusa/rugs/colonial-mills-braided-indoorout...    USA      None
# 27  /rugsusa/rugs/colonial-mills-braided-indoorout...    USA      None
# 28  /rugsusa/rugs/colonial-mills-braided-indoorout...    USA      None
#
#               material weave weave_feature  color           brand imageName  \
# 0   100% Polypropylene  None       Braided  White  Colonial Mills   108BR12
# 1   100% Polypropylene  None       Braided  White  Colonial Mills   108BR12
# 2   100% Polypropylene  None       Braided  White  Colonial Mills   108BR12
# 3   100% Polypropylene  None       Braided  White  Colonial Mills   108BR12
# 4   100% Polypropylene  None       Braided  White  Colonial Mills   108BR12
# 5   100% Polypropylene  None       Braided  White  Colonial Mills   108BR12
# 6   100% Polypropylene  None       Braided  White  Colonial Mills   108BR12
# 7   100% Polypropylene  None       Braided  White  Colonial Mills   108BR12
# 8   100% Polypropylene  None       Braided  White  Colonial Mills   108BR12
# 9   100% Polypropylene  None       Braided  White  Colonial Mills   108BR12
# 10  100% Polypropylene  None       Braided  White  Colonial Mills   108BR12
# 11  100% Polypropylene  None       Braided  White  Colonial Mills   108BR12
# 12  100% Polypropylene  None       Braided  White  Colonial Mills   108BR12
# 13  100% Polypropylene  None       Braided  White  Colonial Mills   108BR12
# 14  100% Polypropylene  None       Braided  White  Colonial Mills   108BR12
# 15  100% Polypropylene  None       Braided  White  Colonial Mills   108BR12
# 16  100% Polypropylene  None       Braided  White  Colonial Mills   108BR12
# 17  100% Polypropylene  None       Braided  White  Colonial Mills   108BR12
# 18  100% Polypropylene  None       Braided  White  Colonial Mills   108BR12
# 19  100% Polypropylene  None       Braided  White  Colonial Mills   108BR12
# 20  100% Polypropylene  None       Braided  White  Colonial Mills   108BR12
# 21  100% Polypropylene  None       Braided  White  Colonial Mills   108BR12
# 22  100% Polypropylene  None       Braided  White  Colonial Mills   108BR12
# 23  100% Polypropylene  None       Braided  White  Colonial Mills   108BR12
# 24  100% Polypropylene  None       Braided  White  Colonial Mills   108BR12
# 25  100% Polypropylene  None       Braided  White  Colonial Mills   108BR12
# 26  100% Polypropylene  None       Braided  White  Colonial Mills   108BR12
# 27  100% Polypropylene  None       Braided  White  Colonial Mills   108BR12
# 28  100% Polypropylene  None       Braided  White  Colonial Mills   108BR12
#
#     imageType                          internalName    category  min_price  \
# 0   roomImage  colonial-mills-braided-indooroutdoor  Boca Raton          0
# 1   roomImage  colonial-mills-braided-indooroutdoor  Boca Raton          0
# 2   roomImage  colonial-mills-braided-indooroutdoor  Boca Raton          0
# 3   roomImage  colonial-mills-braided-indooroutdoor  Boca Raton          0
# 4   roomImage  colonial-mills-braided-indooroutdoor  Boca Raton          0
# 5   roomImage  colonial-mills-braided-indooroutdoor  Boca Raton          0
# 6   roomImage  colonial-mills-braided-indooroutdoor  Boca Raton          0
# 7   roomImage  colonial-mills-braided-indooroutdoor  Boca Raton          0
# 8   roomImage  colonial-mills-braided-indooroutdoor  Boca Raton          0
# 9   roomImage  colonial-mills-braided-indooroutdoor  Boca Raton          0
# 10  roomImage  colonial-mills-braided-indooroutdoor  Boca Raton          0
# 11  roomImage  colonial-mills-braided-indooroutdoor  Boca Raton          0
# 12  roomImage  colonial-mills-braided-indooroutdoor  Boca Raton          0
# 13  roomImage  colonial-mills-braided-indooroutdoor  Boca Raton          0
# 14  roomImage  colonial-mills-braided-indooroutdoor  Boca Raton          0
# 15  roomImage  colonial-mills-braided-indooroutdoor  Boca Raton          0
# 16  roomImage  colonial-mills-braided-indooroutdoor  Boca Raton          0
# 17  roomImage  colonial-mills-braided-indooroutdoor  Boca Raton          0
# 18  roomImage  colonial-mills-braided-indooroutdoor  Boca Raton          0
# 19  roomImage  colonial-mills-braided-indooroutdoor  Boca Raton          0
# 20  roomImage  colonial-mills-braided-indooroutdoor  Boca Raton          0
# 21  roomImage  colonial-mills-braided-indooroutdoor  Boca Raton          0
# 22  roomImage  colonial-mills-braided-indooroutdoor  Boca Raton          0
# 23  roomImage  colonial-mills-braided-indooroutdoor  Boca Raton          0
# 24  roomImage  colonial-mills-braided-indooroutdoor  Boca Raton          0
# 25  roomImage  colonial-mills-braided-indooroutdoor  Boca Raton          0
# 26  roomImage  colonial-mills-braided-indooroutdoor  Boca Raton          0
# 27  roomImage  colonial-mills-braided-indooroutdoor  Boca Raton          0
# 28  roomImage  colonial-mills-braided-indooroutdoor  Boca Raton          0
#
#     max_price availability  aggregate clearance  \
# 0           0       5 Days       True         N
# 1           0       5 Days       True         N
# 2           0       5 Days       True         N
# 3           0       5 Days       True         N
# 4           0       5 Days       True         N
# 5           0       5 Days       True         N
# 6           0       5 Days       True         N
# 7           0       5 Days       True         N
# 8           0       5 Days       True         N
# 9           0       5 Days       True         N
# 10          0       5 Days       True         N
# 11          0       5 Days       True         N
# 12          0       5 Days       True         N
# 13          0       5 Days       True         N
# 14          0       5 Days       True         N
# 15          0       5 Days       True         N
# 16          0       5 Days       True         N
# 17          0       5 Days       True         N
# 18          0       5 Days       True         N
# 19          0       5 Days       True         N
# 20          0       5 Days       True         N
# 21          0       5 Days       True         N
# 22          0       5 Days       True         N
# 23          0       5 Days       True         N
# 24          0       5 Days       True         N
# 25          0       5 Days       True         N
# 26          0       5 Days       True         N
# 27          0       5 Days       True         N
# 28          0       5 Days       True         N
#
#                                      long_description shopbyroom  \
# 0   Just pick a color…any color…they are all here!...       None
# 1   Just pick a color…any color…they are all here!...       None
# 2   Just pick a color…any color…they are all here!...       None
# 3   Just pick a color…any color…they are all here!...       None
# 4   Just pick a color…any color…they are all here!...       None
# 5   Just pick a color…any color…they are all here!...       None
# 6   Just pick a color…any color…they are all here!...       None
# 7   Just pick a color…any color…they are all here!...       None
# 8   Just pick a color…any color…they are all here!...       None
# 9   Just pick a color…any color…they are all here!...       None
# 10  Just pick a color…any color…they are all here!...       None
# 11  Just pick a color…any color…they are all here!...       None
# 12  Just pick a color…any color…they are all here!...       None
# 13  Just pick a color…any color…they are all here!...       None
# 14  Just pick a color…any color…they are all here!...       None
# 15  Just pick a color…any color…they are all here!...       None
# 16  Just pick a color…any color…they are all here!...       None
# 17  Just pick a color…any color…they are all here!...       None
# 18  Just pick a color…any color…they are all here!...       None
# 19  Just pick a color…any color…they are all here!...       None
# 20  Just pick a color…any color…they are all here!...       None
# 21  Just pick a color…any color…they are all here!...       None
# 22  Just pick a color…any color…they are all here!...       None
# 23  Just pick a color…any color…they are all here!...       None
# 24  Just pick a color…any color…they are all here!...       None
# 25  Just pick a color…any color…they are all here!...       None
# 26  Just pick a color…any color…they are all here!...       None
# 27  Just pick a color…any color…they are all here!...       None
# 28  Just pick a color…any color…they are all here!...       None
#
#            dw_insert_timestamp
# 0   2022-01-13 19:33:41.513542
# 1   2022-01-13 19:33:41.513542
# 2   2022-01-13 19:33:41.513542
# 3   2022-01-13 19:33:41.513542
# 4   2022-01-13 19:33:41.513542
# 5   2022-01-13 19:33:41.513542
# 6   2022-01-13 19:33:41.513542
# 7   2022-01-13 19:33:41.513542
# 8   2022-01-13 19:33:41.513542
# 9   2022-01-13 19:33:41.513542
# 10  2022-01-13 19:33:41.513542
# 11  2022-01-13 19:33:41.513542
# 12  2022-01-13 19:33:41.513542
# 13  2022-01-13 19:33:41.513542
# 14  2022-01-13 19:33:41.513542
# 15  2022-01-13 19:33:41.513542
# 16  2022-01-13 19:33:41.513542
# 17  2022-01-13 19:33:41.513542
# 18  2022-01-13 19:33:41.513542
# 19  2022-01-13 19:33:41.513542
# 20  2022-01-13 19:33:41.513542
# 21  2022-01-13 19:33:41.513542
# 22  2022-01-13 19:33:41.513542
# 23  2022-01-13 19:33:41.513542
# 24  2022-01-13 19:33:41.513542
# 25  2022-01-13 19:33:41.513542
# 26  2022-01-13 19:33:41.513542
# 27  2022-01-13 19:33:41.513542
# 28  2022-01-13 19:33:41.513542

# %%
df = query(
    """
    with deduped_parent as (Select distinct * from rugs_usa_parent),
    deduped_variant as (Select distinct * from rugs_usa_variant)

    Select p.weave_feature, v.weave_cat, count(1)
    from deduped_parent p 
    full outer join deduped_variant v
    on p.pid = v.pid
    group by 1,2
    order by 2,3 desc
    """
)

# %%
df.head(50)
# Out:
#          weave_feature     weave_cat  count
# 0                 None       Braided   7107
# 1              Braided       Braided   5626
# 2         Hand Braided       Braided    888
# 3           Hand Woven       Braided    179
# 4           Flat Braid       Braided     95
# 5      Machine Braided       Braided     88
# 6          Hand Loomed       Braided      6
# 7             Handmade       Braided      5
# 8           Hand Woven     Flatweave    924
# 9            Flatweave     Flatweave    734
# 10                None     Flatweave    527
# 11         Hand Loomed     Flatweave    365
# 12           Handwoven     Flatweave     39
# 13            Handmade     Flatweave     31
# 14         Hand Tufted     Flatweave     16
# 15  Hand-Woven Dhurrie     Flatweave      5
# 16                None   Hand Hooked    196
# 17         Hand Hooked   Hand Hooked    150
# 18            Handmade   Hand Hooked     49
# 19        Hand Crafted   Hand Hooked     15
# 20         Hand Tufted   Hand Hooked     11
# 21         Hand Loomed   Hand Hooked      3
# 22           Flatweave   Hand Hooked      2
# 23        Hand Knotted  Hand Knotted     76
# 24                None  Hand Knotted     47
# 25          Hand Woven  Hand Knotted      2
# 26         Hand Tufted   Hand Tufted   3144
# 27                None   Hand Tufted   2270
# 28            Handmade   Hand Tufted    546
# 29          Hand Woven   Hand Tufted    252
# 30        Hand Crafted   Hand Tufted    135
# 31         Hand Loomed   Hand Tufted     91
# 32       Hand Handloom   Hand Tufted     59
# 33           Hand Made   Hand Tufted     25
# 34         Hand-Tufted   Hand Tufted     18
# 35       Hand Stitched   Hand Tufted     12
# 36          Hand-woven   Hand Tufted     12
# 37         Handcrafted   Hand Tufted     10
# 38          Loom Woven   Hand Tufted      4
# 39    Circular Knitted   Hand Tufted      3
# 40        Machine Made  Machine Made  23582
# 41                None  Machine Made  10670
# 42       Machine Woven  Machine Made   1168
# 43        Power Loomed  Machine Made    282
# 44     Machine Braided  Machine Made    198
# 45             Printed  Machine Made     41
# 46      Machine Tufted  Machine Made     34
# 47         Hand Loomed  Machine Made     24
# 48     Machine Printed  Machine Made      3
# 49           Flatweave  Machine Made      2

# %% [markdown]
# # Pads upsell

# %%
scout = PkScout('rugs_usa_pads_upsell')
joint = scout.find_pk()
# Out:
# ['pad_id', 'p_id', 'price', 'variant', 'size', 'stock'] are a candidate: Same cardinality as table row count = 96703
# ['p_id', 'price', 'variant', 'size', 'stock'] are a candidate: Same cardinality as table row count = 96703

# %%
scout.compute_joint_cardinality(['p_id', 'pad_id', 'variant', 'stock'])
# Out:
# 96703

# %%
scout.compute_joint_cardinality(['p_id', 'variant'])
# Out:
# 33022

# %%
query("Select p_id, pad_id, variant, count(distinct stock) from rugs_usa_pads_upsell group by 1,2,3 order by 4 desc")
# Out:
#               p_id             pad_id variant  count
# 0         108SM301     200AFPD01A-609    709O      2
# 1         108SM501    200JAPD1A-58088    709O      2
# 2         108SM301    200JAPD1A-58088    709O      2
# 3         108SM501     200AFPD01A-609    709O      2
# 4       158M342TEL     200AFPD01A-208    2608      2
# ...            ...                ...     ...    ...
# 96685  200MTVS176B    200MTVS176B-508     508      0
# 96686  200MTVS176B    200MTVS176B-609     609      0
# 96687  200MTVS176B  200MTVS176B-76096   76096      0
# 96688  200MTVS176B   200MTVS176B-R404    R404      0
# 96689  200MTVS176B   200MTVS176B-R606    R606      0
#
# [96690 rows x 4 columns]

# %%
query("Select * from rugs_usa_pads_upsell where p_id = '108SM301' and variant = '709O' and pad_id='200AFPD01A-609' ")
# Out:
#       size      shape  price  width  sqft     type  stock  height variant  \
# 0  6' x 9'  Rectangle  65.99    6.0  54.0  premium   4669     9.0    709O
# 1  6' x 9'  Rectangle  65.99    6.0  54.0  premium   4668     9.0    709O
#
#        p_id          pad_id         dw_insert_timestamp
# 0  108SM301  200AFPD01A-609  2022-01-13 20:44:54.227965
# 1  108SM301  200AFPD01A-609  2022-01-13 20:44:54.227965

# %%
query("Select distinct * from rugs_usa_variant where pid='108SM301' and variant='709O' ")
# Out:
#         pid variant  actual_size weave_feature weave_cat size_grp  \
# 0  108SM301    709O  7_ft x 9_ft          None   Braided      6x9
#
#      shipping_size shape  weight  price   msrp  stock_level depletion_level  \
# 0  W ? x L ? x H ?  Oval    65.0  724.0  646.8          100            None
#
#    low_stock estimated_delivery_date this_isd_range    status origin  \
# 0      False                      NA             NA  In_stock   None
#
#   new_arrival stockMsg stockEddMsg  other_stock_core  other_stock_compass  \
# 0           N       NA          NA                 0                    0
#
#           dw_insert_timestamp
# 0  2022-01-13 19:33:41.513970

# %% [markdown]
# # Links

# %%
scout = PkScout('rugs_usa_links')
joint = scout.find_pk()
# Out:
# request_time_stamp is a candidate: Same cardinality as table row count = 5565
# ['request_time_stamp', 'card_links'] are a candidate: Same cardinality as table row count = 5565

# %%
query("Select base_url, count(distinct page_links), count(distinct card_links) from rugs_usa_links group by 1")
# Out:
#                                             base_url  count  count
# 0  https://www.rugsusa.com/rugsusa/control/search...     93   5550

# %%
query("Select distinct base_url from rugs_usa_links").iloc[0].values
# Out:
# array(['https://www.rugsusa.com/rugsusa/control/search-rugs'],
#       dtype=object)

# %%
query("Select distinct page_links from rugs_usa_links").iloc[0:50].values
# Out:
# array([['https://www.rugsusa.com/rugsusa/control/search-rugs?p=23'],
#        ['https://www.rugsusa.com/rugsusa/control/search-rugs?p=11'],
#        ['https://www.rugsusa.com/rugsusa/control/search-rugs?p=58'],
#        ['https://www.rugsusa.com/rugsusa/control/search-rugs?p=14'],
#        ['https://www.rugsusa.com/rugsusa/control/search-rugs?p=76'],
#        ['https://www.rugsusa.com/rugsusa/control/search-rugs?p=63'],
#        ['https://www.rugsusa.com/rugsusa/control/search-rugs?p=8'],
#        ['https://www.rugsusa.com/rugsusa/control/search-rugs?p=24'],
#        ['https://www.rugsusa.com/rugsusa/control/search-rugs?p=68'],
#        ['https://www.rugsusa.com/rugsusa/control/search-rugs?p=18'],
#        ['https://www.rugsusa.com/rugsusa/control/search-rugs?p=56'],
#        ['https://www.rugsusa.com/rugsusa/control/search-rugs?p=17'],
#        ['https://www.rugsusa.com/rugsusa/control/search-rugs?p=36'],
#        ['https://www.rugsusa.com/rugsusa/control/search-rugs?p=21'],
#        ['https://www.rugsusa.com/rugsusa/control/search-rugs?p=92'],
#        ['https://www.rugsusa.com/rugsusa/control/search-rugs?p=70'],
#        ['https://www.rugsusa.com/rugsusa/control/search-rugs?p=19'],
#        ['https://www.rugsusa.com/rugsusa/control/search-rugs?p=57'],
#        ['https://www.rugsusa.com/rugsusa/control/search-rugs?p=41'],
#        ['https://www.rugsusa.com/rugsusa/control/search-rugs?p=4'],
#        ['https://www.rugsusa.com/rugsusa/control/search-rugs?p=62'],
#        ['https://www.rugsusa.com/rugsusa/control/search-rugs?p=32'],
#        ['https://www.rugsusa.com/rugsusa/control/search-rugs?p=74'],
#        ['https://www.rugsusa.com/rugsusa/control/search-rugs?p=20'],
#        ['https://www.rugsusa.com/rugsusa/control/search-rugs?p=16'],
#        ['https://www.rugsusa.com/rugsusa/control/search-rugs?p=82'],
#        ['https://www.rugsusa.com/rugsusa/control/search-rugs?p=2'],
#        ['https://www.rugsusa.com/rugsusa/control/search-rugs?p=49'],
#        ['https://www.rugsusa.com/rugsusa/control/search-rugs?p=30'],
#        ['https://www.rugsusa.com/rugsusa/control/search-rugs?p=47'],
#        ['https://www.rugsusa.com/rugsusa/control/search-rugs?p=15'],
#        ['https://www.rugsusa.com/rugsusa/control/search-rugs?p=87'],
#        ['https://www.rugsusa.com/rugsusa/control/search-rugs?p=39'],
#        ['https://www.rugsusa.com/rugsusa/control/search-rugs?p=80'],
#        ['https://www.rugsusa.com/rugsusa/control/search-rugs?p=55'],
#        ['https://www.rugsusa.com/rugsusa/control/search-rugs?p=29'],
#        ['https://www.rugsusa.com/rugsusa/control/search-rugs?p=86'],
#        ['https://www.rugsusa.com/rugsusa/control/search-rugs?p=40'],
#        ['https://www.rugsusa.com/rugsusa/control/search-rugs?p=84'],
#        ['https://www.rugsusa.com/rugsusa/control/search-rugs?p=75'],
#        ['https://www.rugsusa.com/rugsusa/control/search-rugs?p=35'],
#        ['https://www.rugsusa.com/rugsusa/control/search-rugs?p=79'],
#        ['https://www.rugsusa.com/rugsusa/control/search-rugs?p=67'],
#        ['https://www.rugsusa.com/rugsusa/control/search-rugs?p=28'],
#        ['https://www.rugsusa.com/rugsusa/control/search-rugs?p=37'],
#        ['https://www.rugsusa.com/rugsusa/control/search-rugs?p=61'],
#        ['https://www.rugsusa.com/rugsusa/control/search-rugs?p=59'],
#        ['https://www.rugsusa.com/rugsusa/control/search-rugs?p=10'],
#        ['https://www.rugsusa.com/rugsusa/control/search-rugs?p=25'],
#        ['https://www.rugsusa.com/rugsusa/control/search-rugs?p=91']],
#       dtype=object)

# %%
query("Select page_links, count(distinct card_links) from rugs_usa_links group by 1")['count'].value_counts()
# Out:
# count
# 60    90
# 58     1
# 55     1
# 45     1
# Name: count, dtype: int64

# %%
df = query("Select page_links, count(distinct card_links) from rugs_usa_links group by 1")
df[df['count'] == 45].page_links.values
# Out:
# array(['https://www.rugsusa.com/rugsusa/control/search-rugs?p=93'],
#       dtype=object)

# %%
df[df['count'] == 55].page_links.values
# Out:
# array(['https://www.rugsusa.com/rugsusa/control/search-rugs?p=91'],
#       dtype=object)

# %%
df[df['count'] == 58].page_links.values
# Out:
# array(['https://www.rugsusa.com/rugsusa/control/search-rugs?p=84'],
#       dtype=object)

# %%
query("Select distinct card_links from rugs_usa_links").iloc[1].values
# Out:
# array(['https://www.rugsusa.com//rugsusa/rugs/rugs-usa-retro-aztec-indooroutdoor/Rust/200HJOA07A-P.html'],
#       dtype=object)

# %% [markdown]
# # Color map

# %%
scout = PkScout('rugs_usa_color_map')
joint = scout.find_pk()
# Out:
# color_id is a candidate: Same cardinality as table row count = 5640
# ['color_id', 'pid'] are a candidate: Same cardinality as table row count = 5640
# ['pid', 'color_value'] are a candidate: Same cardinality as table row count = 5640

# %%
scout.compute_joint_cardinality(['pid'])
# Out:
# 3404

# %%
query("Select color_value, count(distinct color_id), count(distinct pid), count(1) from rugs_usa_color_map group by 1 order by 2").head(50)
# Out:
#          color_value  count  count  count
# 0          Red Black      1      1      8
# 1              Adobe      1      1      5
# 2               Aero      1      1      6
# 3      African Plain      1      1      7
# 4           Gunmetal      1      1      9
# 5        Harbor Gray      1      1      1
# 6      Harvest Ebony      1      1      5
# 7          Hazy Blue      1      1      7
# 8        Hazy Forest      1      1      5
# 9        Hearthstone      1      1      9
# 10      Heather Gray      1      1      2
# 11    Heathered Rose      1      1      5
# 12          Heirloom      1      1      6
# 13       Holly Berry      1      1     16
# 14          Hot Pink      1      1      1
# 15            Hunter      1      1      1
# 16        IVORY Gray      1      1      3
# 17         India Ink      1      1      7
# 18        Indian Red      1      1      1
# 19           Ireland      1      1      5
# 20          Iron Ore      1      1      3
# 21    Ivory Charcoal      1      1      3
# 22        Ivory Navy      1      1      1
# 23         Ivory Red      1      1      1
# 24              Jade      1      1      7
# 25              Jute      1      1      9
# 26      Kaleidoscope      1      1      2
# 27            Lagoon      1      1      5
# 28         Lambswool      1      1      9
# 29   Lapis Sandstone      1      1      5
# 30         Lava Flow      1      1      1
# 31     Lavender Gray      1      1     15
# 32        Lemongrass      1      1      9
# 33           Leopard      1      1      1
# 34           Liberty      1      1      3
# 35    Light Amethyst      1      1      5
# 36        Light Aqua      1      1      4
# 37       Light Maize      1      1      5
# 38   Light Turquoise      1      1      1
# 39    Lily Pad Green      1      1      8
# 40        Lime Twist      1      1      8
# 41         Limestone      1      1      6
# 42             Maple      1      1      5
# 43            Marble      1      1      6
# 44           Mariner      1      1      1
# 45     Medieval Blue      1      1      1
# 46       Medium Gray      1      1      2
# 47    Metallic Beige      1      1      1
# 48  Midnight Heather      1      1      1
# 49      Midnight Red      1      1      5

# %% [markdown]
# # Category map

# %%
scout = PkScout('rugs_usa_category_map')
joint = scout.find_pk()
# Out:
# ['pid', 'category_id'] are a candidate: Same cardinality as table row count = 31758

# %%
scout.compute_joint_cardinality(['pid', 'category_id'])
# Out:
# 31758

# %%
query("Select * from rugs_usa_category_map")
# Out:
#              pid               category_id            category_value  \
# 0      200TAJT03                     11265                      Maui
# 1      200TAJT03                     12199           Solid & Striped
# 2      200TAJT03                     12327               Serendipity
# 3      200TAJT03                     17951                   Casuals
# 4      200TAJT03                      7001                   Casuals
# ...          ...                       ...                       ...
# 51260    108BN19                     13030                  Brooklyn
# 51261    108BN19                      7104                   Outdoor
# 51262    108BN19                      9966                   Casuals
# 51263    108BN19  COLONIAL_MILLS_PROMO_CAT  Colonial Mills Promo Cat
# 51264    108BN19                 MADEINUSA               MADE IN USA
#
#               dw_insert_timestamp
# 0      2022-01-13 19:33:41.514826
# 1      2022-01-13 19:33:41.514826
# 2      2022-01-13 19:33:41.514826
# 3      2022-01-13 19:33:41.514826
# 4      2022-01-13 19:33:41.514826
# ...                           ...
# 51260  2022-01-13 19:33:41.514826
# 51261  2022-01-13 19:33:41.514826
# 51262  2022-01-13 19:33:41.514826
# 51263  2022-01-13 19:33:41.514826
# 51264  2022-01-13 19:33:41.514826
#
# [51265 rows x 4 columns]

# %% [markdown]
# # What is PID?

# %%
df = query(
    """
    Select pid, 'rugs_usa_parent' as tbl
    from rugs_usa_parent
    union
    Select pid, 'rugs_usa_variant' as tbl
    from rugs_usa_variant
    union
    Select p_id as pid, 'rugs_usa_pads_upsell' as tbl
    from rugs_usa_pads_upsell
    """
)

# %%
df.groupby('pid').apply(lambda x: "|".join(sorted(x['tbl']))).value_counts()
# Out:
# /var/folders/83/092jbldj2h95s7jxz6jlh2380000gn/T/ipykernel_92701/2491901396.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df.groupby('pid').apply(lambda x: "|".join(sorted(x['tbl']))).value_counts()
# rugs_usa_pads_upsell|rugs_usa_parent|rugs_usa_variant    3222
# rugs_usa_pads_upsell|rugs_usa_variant                    2313
# rugs_usa_parent                                           165
# rugs_usa_parent|rugs_usa_variant                           17
# rugs_usa_variant                                            3
# Name: count, dtype: int64

# %% [markdown]
# # What is variant

# %%
df = query(
    """
    Select variant, 'rugs_usa_variant' as tbl
    from rugs_usa_variant
    union
    Select variant, 'rugs_usa_pads_upsell' as tbl
    from rugs_usa_pads_upsell
    """
)

# %%
df.groupby('variant').apply(lambda x: "|".join(sorted(x['tbl']))).value_counts()
# Out:
# /var/folders/83/092jbldj2h95s7jxz6jlh2380000gn/T/ipykernel_92701/4018115695.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df.groupby('variant').apply(lambda x: "|".join(sorted(x['tbl']))).value_counts()
# rugs_usa_pads_upsell|rugs_usa_variant    557
# rugs_usa_variant                          30
# Name: count, dtype: int64
